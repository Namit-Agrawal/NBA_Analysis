# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('toppick_records3.csv')

# %%
list(df.columns)[20:]
# Out:
# ['ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS',
#  'dummy',
#  'SOS',
#  'NBAGP',
#  'NBATRB',
#  'NBAAST',
#  'NBASTL',
#  'NBABLK',
#  'NBAPTS']

# %%
df.iloc[1346:][list(df.columns)[20:]]=df.iloc[1346:][list(df.columns)[20:]].shift(periods=2, axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df.drop([1295,1312,1414], inplace=True)

# %%
df.drop(['Unnamed: 0', 'dummy'], axis=1, inplace=True)

# %%
df
# Out:
#              playerName Pos              School  Conf      G     GS    MP  \
# 0         Deandre Ayton   C             Arizona   NaN   35.0   35.0  33.5
# 1     Marvin Bagley III  PF                Duke   NaN   33.0   32.0  33.9
# 2     Jaren Jackson Jr.  PF      Michigan State   NaN   35.0   34.0  21.8
# 3            Trae Young  PG            Oklahoma   NaN   32.0   32.0  35.4
# 4              Mo Bamba   C               Texas   NaN   30.0   29.0  30.2
# ...                 ...  ..                 ...   ...    ...    ...   ...
# 1471       Willie White  SG         Chattanooga   NaN  122.0  119.0  33.7
# 1472       Gary Plummer  PF   Boston University   NaN   90.0   50.0  24.5
# 1473       Ben McDonald  SF           UC-Irvine   NaN  114.0   57.0  33.9
# 1474       Jim Petersen  PF           Minnesota   NaN   96.0    NaN  18.5
# 1475         Joe Binion  PF  North Carolina A&T   NaN  116.0    NaN   NaN
#
#        FG   FGA    FG%  ...  TOV   PF   PTS    SOS  NBAGP  NBATRB  NBAAST  \
# ...

# %%
rookie_data = df[['NBAGP', 'NBATRB', 'NBAAST', 'NBASTL', 'NBABLK', 'NBAPTS']]

# %%
rookie_data
# Out:
#       NBAGP  NBATRB  NBAAST  NBASTL  NBABLK  NBAPTS
# 0      71.0    10.3     1.8     0.9     0.9    16.3
# 1      62.0     7.6     1.0     0.5     1.0    14.9
# 2      58.0     4.7     1.1     0.9     1.4    13.8
# 3      81.0     3.7     8.1     0.9     0.2    19.1
# 4      47.0     5.0     0.8     0.3     1.4     6.2
# ...     ...     ...     ...     ...     ...     ...
# 1471   39.0     0.9     0.7     0.1     0.1     3.3
# 1472   66.0     2.0     0.4     0.2     0.2     3.8
# 1473   21.0     1.8     0.4     0.3     0.0     2.9
# 1474   60.0     2.5     0.5     0.2     0.5     3.2
# 1475   11.0     1.6     0.1     0.2     0.2     1.3
#
# [1473 rows x 6 columns]

# %%
df.drop(['NBAGP', 'NBATRB', 'NBAAST', 'NBASTL', 'NBABLK', 'NBAPTS'], axis=1, inplace=True)

# %%
df
# Out:
#              playerName Pos              School  Conf      G     GS    MP  \
# 0         Deandre Ayton   C             Arizona   NaN   35.0   35.0  33.5
# 1     Marvin Bagley III  PF                Duke   NaN   33.0   32.0  33.9
# 2     Jaren Jackson Jr.  PF      Michigan State   NaN   35.0   34.0  21.8
# 3            Trae Young  PG            Oklahoma   NaN   32.0   32.0  35.4
# 4              Mo Bamba   C               Texas   NaN   30.0   29.0  30.2
# ...                 ...  ..                 ...   ...    ...    ...   ...
# 1471       Willie White  SG         Chattanooga   NaN  122.0  119.0  33.7
# 1472       Gary Plummer  PF   Boston University   NaN   90.0   50.0  24.5
# 1473       Ben McDonald  SF           UC-Irvine   NaN  114.0   57.0  33.9
# 1474       Jim Petersen  PF           Minnesota   NaN   96.0    NaN  18.5
# 1475         Joe Binion  PF  North Carolina A&T   NaN  116.0    NaN   NaN
#
#        FG   FGA    FG%  ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  \
# ...

# %%
pos = pd.get_dummies(df['Pos'])
pos['C'] = pos['C']+pos['C-PF']
pos['PF'] = pos['PF']+pos['PF-C']+pos['PF-SF']
pos['SF'] = pos['SF']+pos['SF-PF']+pos['SF-SG']
pos['SG'] = pos['SG']+pos['SG-PG']+pos['SG-SF']

# %%
df = pd.concat([df,pos], axis=1)

# %%
df
# Out:
#              playerName Pos              School  Conf      G     GS    MP  \
# 0         Deandre Ayton   C             Arizona   NaN   35.0   35.0  33.5
# 1     Marvin Bagley III  PF                Duke   NaN   33.0   32.0  33.9
# 2     Jaren Jackson Jr.  PF      Michigan State   NaN   35.0   34.0  21.8
# 3            Trae Young  PG            Oklahoma   NaN   32.0   32.0  35.4
# 4              Mo Bamba   C               Texas   NaN   30.0   29.0  30.2
# ...                 ...  ..                 ...   ...    ...    ...   ...
# 1471       Willie White  SG         Chattanooga   NaN  122.0  119.0  33.7
# 1472       Gary Plummer  PF   Boston University   NaN   90.0   50.0  24.5
# 1473       Ben McDonald  SF           UC-Irvine   NaN  114.0   57.0  33.9
# 1474       Jim Petersen  PF           Minnesota   NaN   96.0    NaN  18.5
# 1475         Joe Binion  PF  North Carolina A&T   NaN  116.0    NaN   NaN
#
#        FG   FGA    FG%  ...  PF  PF-C  PF-SF  PG  SF  SF-PF  SF-SG  SG  SG-PG  \
# ...

# %%
df.drop(['Pos','C-PF', 'PF-C', 'PF-SF', 'SF-PF', 'SF-SG', 'SG-PG', 'SG-SF'], axis=1, inplace=True)

# %%
df
# Out:
#              playerName              School  Conf      G     GS    MP   FG  \
# 0         Deandre Ayton             Arizona   NaN   35.0   35.0  33.5  7.9
# 1     Marvin Bagley III                Duke   NaN   33.0   32.0  33.9  8.2
# 2     Jaren Jackson Jr.      Michigan State   NaN   35.0   34.0  21.8  3.4
# 3            Trae Young            Oklahoma   NaN   32.0   32.0  35.4  8.2
# 4              Mo Bamba               Texas   NaN   30.0   29.0  30.2  4.9
# ...                 ...                 ...   ...    ...    ...   ...  ...
# 1471       Willie White         Chattanooga   NaN  122.0  119.0  33.7  6.5
# 1472       Gary Plummer   Boston University   NaN   90.0   50.0  24.5  4.9
# 1473       Ben McDonald           UC-Irvine   NaN  114.0   57.0  33.9  5.6
# 1474       Jim Petersen           Minnesota   NaN   96.0    NaN  18.5  2.4
# 1475         Joe Binion  North Carolina A&T   NaN  116.0    NaN   NaN  7.2
#
# ...

# %%
df.drop(['School', 'Conf'], axis=1, inplace=True)

# %%
df
# Out:
#              playerName      G     GS    MP   FG   FGA    FG%   2P   2PA  \
# 0         Deandre Ayton   35.0   35.0  33.5  7.9  12.9  0.612  7.5  11.9
# 1     Marvin Bagley III   33.0   32.0  33.9  8.2  13.3  0.614  7.5  11.6
# 2     Jaren Jackson Jr.   35.0   34.0  21.8  3.4   6.6  0.513  2.3   3.9
# 3            Trae Young   32.0   32.0  35.4  8.2  19.3  0.422  4.5   9.1
# 4              Mo Bamba   30.0   29.0  30.2  4.9   9.0  0.541  4.4   7.3
# ...                 ...    ...    ...   ...  ...   ...    ...  ...   ...
# 1471       Willie White  122.0  119.0  33.7  6.5  12.8  0.509  5.6  11.4
# 1472       Gary Plummer   90.0   50.0  24.5  4.9  10.1  0.487  NaN   NaN
# 1473       Ben McDonald  114.0   57.0  33.9  5.6  10.7  0.523  NaN   NaN
# 1474       Jim Petersen   96.0    NaN  18.5  2.4   4.2  0.575  NaN   NaN
# 1475         Joe Binion  116.0    NaN   NaN  7.2  14.4  0.502  NaN   NaN
#
#         2P%  ...  BLK  TOV   PF   PTS    SOS  C  PF  PG  SF  SG
# ...

# %%
df['NBAPTS'] = rookie_data['NBAPTS']

# %%
df
# Out:
#              playerName      G     GS    MP   FG   FGA    FG%   2P   2PA  \
# 0         Deandre Ayton   35.0   35.0  33.5  7.9  12.9  0.612  7.5  11.9
# 1     Marvin Bagley III   33.0   32.0  33.9  8.2  13.3  0.614  7.5  11.6
# 2     Jaren Jackson Jr.   35.0   34.0  21.8  3.4   6.6  0.513  2.3   3.9
# 3            Trae Young   32.0   32.0  35.4  8.2  19.3  0.422  4.5   9.1
# 4              Mo Bamba   30.0   29.0  30.2  4.9   9.0  0.541  4.4   7.3
# ...                 ...    ...    ...   ...  ...   ...    ...  ...   ...
# 1471       Willie White  122.0  119.0  33.7  6.5  12.8  0.509  5.6  11.4
# 1472       Gary Plummer   90.0   50.0  24.5  4.9  10.1  0.487  NaN   NaN
# 1473       Ben McDonald  114.0   57.0  33.9  5.6  10.7  0.523  NaN   NaN
# 1474       Jim Petersen   96.0    NaN  18.5  2.4   4.2  0.575  NaN   NaN
# 1475         Joe Binion  116.0    NaN   NaN  7.2  14.4  0.502  NaN   NaN
#
#         2P%  ...  TOV   PF   PTS    SOS  C  PF  PG  SF  SG  NBAPTS
# ...

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVC

# %%
X_train, X_test, y_train, y_test = train_test_split(df.dropna().drop(['playerName','NBAPTS'],axis=1), df.dropna()['NBAPTS'], test_size=0.3, random_state=101)
rf = RandomForestRegressor(n_estimators=2000, random_state=101)
rf.fit(X_train, y_train)
predictions = rf.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

ef = ExtraTreesRegressor(n_estimators=2000, random_state=101)
ef.fit(X_train, y_train)
predictions2 = ef.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, predictions2))
print('MSE:', metrics.mean_squared_error(y_test, predictions2))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions2)))
# Out:
# MAE: 2.898680456852792
# MSE: 13.201954742677657
# RMSE: 3.63344942756572
# MAE: 2.8654560913705605
# MSE: 13.119290220088837
# RMSE: 3.6220560763313476

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

model.add(Dense(30,activation='relu'))
model.add(Dense(30,activation='relu'))
model.add(Dense(30,activation='relu'))
model.add(Dense(1, activation='relu'))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_test,y_test.values),
          epochs=400)
# Out:
# Train on 458 samples, validate on 197 samples
# Epoch 1/400
# 458/458 [==============================] - 0s 674us/sample - loss: 45.6656 - val_loss: 37.1337
# Epoch 2/400
# 458/458 [==============================] - 0s 64us/sample - loss: 36.8114 - val_loss: 27.8607
# Epoch 3/400
# 458/458 [==============================] - 0s 61us/sample - loss: 25.4706 - val_loss: 16.8646
# Epoch 4/400
# 458/458 [==============================] - 0s 56us/sample - loss: 15.9628 - val_loss: 15.0363
# Epoch 5/400
# 458/458 [==============================] - 0s 63us/sample - loss: 15.4531 - val_loss: 14.3880
# Epoch 6/400
# 458/458 [==============================] - 0s 57us/sample - loss: 14.8833 - val_loss: 14.2858
# Epoch 7/400
# 458/458 [==============================] - 0s 61us/sample - loss: 14.6897 - val_loss: 14.1660
# Epoch 8/400
# 458/458 [==============================] - 0s 68us/sample - loss: 14.5610 - val_loss: 14.0722
# Epoch 9/400
# ...

# %%
# Out:
#          G     GS    MP   FG   FGA    FG%   2P   2PA    2P%   3P  ...  STL  \
# 564   92.0   91.0  35.2  7.2  12.4  0.577  7.1  12.2  0.580  0.1  ...  1.3
# 129  132.0   95.0  24.3  4.6   8.6  0.539  4.6   8.4  0.544  0.0  ...  0.4
# 401  124.0   85.0  22.1  2.2   4.0  0.539  2.2   4.0  0.542  0.0  ...  0.4
# 285   35.0   27.0  30.3  5.7  12.8  0.443  5.4  11.2  0.483  0.3  ...  1.9
# 146   39.0   39.0  29.1  4.4   9.1  0.486  3.3   6.3  0.516  1.2  ...  1.3
# ..     ...    ...   ...  ...   ...    ...  ...   ...    ...  ...  ...  ...
# 78   145.0  113.0  30.0  4.2   9.2  0.454  2.9   6.2  0.471  1.3  ...  1.1
# 672  125.0   60.0  28.2  4.4   9.2  0.481  3.3   5.7  0.568  1.2  ...  1.2
# 647  126.0   93.0  33.4  5.8  10.8  0.531  5.6  10.4  0.540  0.1  ...  1.4
# 371  101.0   82.0  23.5  4.1   7.9  0.520  4.1   7.7  0.526  0.0  ...  0.6
# 588  128.0   84.0  25.4  3.5   7.5  0.473  1.9   3.2  0.594  1.6  ...  1.2
#
#      BLK  TOV   PF    SOS  C  PF  PG  SF  SG
# ...

# %%
plt.figure(figsize=(35,35))
sns.heatmap(df.corr(), annot=True, cmap='viridis')

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
import math
def func(x):
    return math.floor(x/10)
df['CateG'] = df['G'].apply(func)
df
# Out:
#              playerName      G     GS    MP   FG   FGA    FG%   2P   2PA  \
# 0         Deandre Ayton   35.0   35.0  33.5  7.9  12.9  0.612  7.5  11.9
# 1     Marvin Bagley III   33.0   32.0  33.9  8.2  13.3  0.614  7.5  11.6
# 2     Jaren Jackson Jr.   35.0   34.0  21.8  3.4   6.6  0.513  2.3   3.9
# 3            Trae Young   32.0   32.0  35.4  8.2  19.3  0.422  4.5   9.1
# 4              Mo Bamba   30.0   29.0  30.2  4.9   9.0  0.541  4.4   7.3
# ...                 ...    ...    ...   ...  ...   ...    ...  ...   ...
# 1471       Willie White  122.0  119.0  33.7  6.5  12.8  0.509  5.6  11.4
# 1472       Gary Plummer   90.0   50.0  24.5  4.9  10.1  0.487  NaN   NaN
# 1473       Ben McDonald  114.0   57.0  33.9  5.6  10.7  0.523  NaN   NaN
# 1474       Jim Petersen   96.0    NaN  18.5  2.4   4.2  0.575  NaN   NaN
# 1475         Joe Binion  116.0    NaN   NaN  7.2  14.4  0.502  NaN   NaN
#
#         2P%  ...   PF   PTS    SOS  C  PF  PG  SF  SG  NBAPTS  CateG
# ...

# %%
CGS=df.groupby('CateG')['GS'].median()
CGS
# Out:
# CateG
# 1       9.0
# 2      23.5
# 3      33.0
# 4      39.0
# 5      52.0
# 6      60.0
# 7      57.0
# 8      59.5
# 9      78.5
# 10     74.0
# 11     70.0
# 12     85.0
# 13    102.5
# 14    106.0
# 15     82.0
# Name: GS, dtype: float64

# %%
def cate(cols):
    GS = cols[0]
    cat = cols[1]
    if pd.isnull(GS):
        return CGS[cat]
    else:
        return GS

# %%
df['GS'] = df[['GS','CateG']].apply(cate,axis=1)

# %%
df
# Out:
#              playerName      G     GS    MP   FG   FGA    FG%   2P   2PA  \
# 0         Deandre Ayton   35.0   35.0  33.5  7.9  12.9  0.612  7.5  11.9
# 1     Marvin Bagley III   33.0   32.0  33.9  8.2  13.3  0.614  7.5  11.6
# 2     Jaren Jackson Jr.   35.0   34.0  21.8  3.4   6.6  0.513  2.3   3.9
# 3            Trae Young   32.0   32.0  35.4  8.2  19.3  0.422  4.5   9.1
# 4              Mo Bamba   30.0   29.0  30.2  4.9   9.0  0.541  4.4   7.3
# ...                 ...    ...    ...   ...  ...   ...    ...  ...   ...
# 1471       Willie White  122.0  119.0  33.7  6.5  12.8  0.509  5.6  11.4
# 1472       Gary Plummer   90.0   50.0  24.5  4.9  10.1  0.487  NaN   NaN
# 1473       Ben McDonald  114.0   57.0  33.9  5.6  10.7  0.523  NaN   NaN
# 1474       Jim Petersen   96.0   78.5  18.5  2.4   4.2  0.575  NaN   NaN
# 1475         Joe Binion  116.0   70.0   NaN  7.2  14.4  0.502  NaN   NaN
#
#         2P%  ...   PF   PTS    SOS  C  PF  PG  SF  SG  NBAPTS  CateG
# ...

# %%
df['CateTRB'] = df['TRB'].apply(round)

# %%
DRBM=df.groupby('CateTRB')['DRB'].median()
DRBM
# Out:
# CateTRB
# 2     1.90
# 3     2.50
# 4     3.00
# 5     3.45
# 6     4.10
# 7     4.80
# 8     5.40
# 9     6.20
# 10    6.80
# 11    7.40
# 12    8.20
# 13    7.30
# 14     NaN
# Name: DRB, dtype: float64

# %%
def cateG(cols):
    DRB = cols[0]
    TRB = cols[1]
    cat = cols[2]
    if pd.isnull(DRB):
        if cat<=4:
            return TRB
        elif cat == 14:
            return 8
        else:
            return DRBM[cat]

    else:
        return DRB

# %%
df['DRB'] = df[['DRB','TRB','CateTRB']].apply(cateG,axis=1)

# %%
def ORBFix(cols):
    DRB = cols[0]
    TRB = cols[1]
    return TRB-DRB

# %%
df['ORB'] = df[['DRB','TRB']].apply(ORBFix,axis=1)

# %%
df.dropna()
# Out:
#              playerName      G     GS    MP   FG   FGA    FG%   2P   2PA  \
# 0         Deandre Ayton   35.0   35.0  33.5  7.9  12.9  0.612  7.5  11.9
# 1     Marvin Bagley III   33.0   32.0  33.9  8.2  13.3  0.614  7.5  11.6
# 2     Jaren Jackson Jr.   35.0   34.0  21.8  3.4   6.6  0.513  2.3   3.9
# 3            Trae Young   32.0   32.0  35.4  8.2  19.3  0.422  4.5   9.1
# 4              Mo Bamba   30.0   29.0  30.2  4.9   9.0  0.541  4.4   7.3
# ...                 ...    ...    ...   ...  ...   ...    ...  ...   ...
# 1454      Tony Campbell  104.0   89.0  31.3  5.7  11.8  0.482  7.6  15.0
# 1459       Ron Anderson   68.0   60.0  36.8  7.1  12.7  0.560  6.7  12.1
# 1464       Steve Colter  107.0   50.0  30.4  4.6   9.4  0.493  5.7  11.1
# 1469        Danny Young  122.0   93.0  28.5  3.7   7.9  0.475  3.8   7.8
# 1471       Willie White  122.0  119.0  33.7  6.5  12.8  0.509  5.6  11.4
#
#         2P%  ...   PTS    SOS  C  PF  PG  SF  SG  NBAPTS  CateG  CateTRB
# ...

# %%
df.drop(['CateG', 'CateTRB'], axis=1, inplace=True)

# %%
plt.figure(figsize=(35,35))
sns.heatmap(df.corr(), annot=True, cmap='viridis')

# %%
X_train, X_test, y_train, y_test = train_test_split(df.dropna().drop(['playerName','GS','NBAPTS'],axis=1), df.dropna()['NBAPTS'], test_size=0.3, random_state=101)
rf = RandomForestRegressor(n_estimators=2000, random_state=101)
rf.fit(X_train, y_train)
predictions = rf.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

ef = ExtraTreesRegressor(n_estimators=2000, random_state=101)
ef.fit(X_train, y_train)
predictions2 = ef.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, predictions2))
print('MSE:', metrics.mean_squared_error(y_test, predictions2))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions2)))

model = SVC(
# Out:
# MAE: 3.2148861823361794
# MSE: 17.41681337963673
# RMSE: 4.173345585934231
# MAE: 3.199559401709399
# MSE: 17.266368258824766
# RMSE: 4.155281971036955

# %%
df
# Out:
#              playerName      G     GS    MP   FG   FGA    FG%   2P   2PA  \
# 0         Deandre Ayton   35.0   35.0  33.5  7.9  12.9  0.612  7.5  11.9
# 1     Marvin Bagley III   33.0   32.0  33.9  8.2  13.3  0.614  7.5  11.6
# 2     Jaren Jackson Jr.   35.0   34.0  21.8  3.4   6.6  0.513  2.3   3.9
# 3            Trae Young   32.0   32.0  35.4  8.2  19.3  0.422  4.5   9.1
# 4              Mo Bamba   30.0   29.0  30.2  4.9   9.0  0.541  4.4   7.3
# ...                 ...    ...    ...   ...  ...   ...    ...  ...   ...
# 1471       Willie White  122.0  119.0  33.7  6.5  12.8  0.509  5.6  11.4
# 1472       Gary Plummer   90.0   50.0  24.5  4.9  10.1  0.487  NaN   NaN
# 1473       Ben McDonald  114.0   57.0  33.9  5.6  10.7  0.523  NaN   NaN
# 1474       Jim Petersen   96.0   78.5  18.5  2.4   4.2  0.575  NaN   NaN
# 1475         Joe Binion  116.0   70.0   NaN  7.2  14.4  0.502  NaN   NaN
#
#         2P%  ...  TOV   PF   PTS    SOS  C  PF  PG  SF  SG  NBAPTS
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df.dropna().drop(['playerName','PTS','NBAPTS'],axis=1), df.dropna()['PTS'], test_size=0.3, random_state=101)
rf = RandomForestRegressor(n_estimators=2000, random_state=101)
rf.fit(X_train, y_train)
predictions = rf.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.3993159544159468
# MSE: 0.32925195925924705
# RMSE: 0.5738048093727056
