# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rookie_data = pd.read_csv('rookie_records.csv')

# %%
rookie_data.head(5)
# Out:
#        player name  GP   TRB   AST   STL   BLK    PTS
# 0  Carmelo Anthony  82  6.07  2.77  1.18  0.50  21.04
# 1       Chris Bosh  75  7.43  1.04  0.79  1.41  11.48
# 2      Dwyane Wade  61  4.05  4.51  1.41  0.56  16.25
# 3      Chris Kaman  82  5.62  1.04  0.28  0.89   6.09
# 4     Kirk Hinrich  76  3.41  6.80  1.33  0.28  12.04

# %%
college_data = pd.read_csv('toppick_records.csv')

# %%
college_data.head(5)
# Out:
#        player name  year  pick position  GP  GS   MIN   FGM    FGA    FG%  \
# 0  Carmelo Anthony  2003     3        F  35  35  36.4  7.91  17.49  0.453
# 1       Chris Bosh  2003     4       PF  31  31  31.0  5.45   9.74  0.560
# 2      Dwyane Wade  2003     5       SG  33  33  32.1  7.61  15.18  0.501
# 3      Chris Kaman  2003     6        C  31  31  34.0  7.87  12.65  0.622
# 4     Kirk Hinrich  2003     7        G  37  37  33.5  6.27  13.19  0.475
#
#    ...    TRB   AST   STL   BLK    PF   TOV    PTS    WS   eFG%    PER
# 0  ...   9.74  2.20  1.49  0.86  2.20  2.20  22.23  7.56  0.498  24.92
# 1  ...   8.97  1.23  0.97  2.13  2.35  2.32  15.71  5.30  0.596  24.61
# 2  ...   6.33  4.39  2.15  1.30  2.30  3.24  21.52  7.17  0.515  31.24
# 3  ...  12.03  1.26  0.61  3.16  3.19  4.42  22.42  6.24  0.622  29.00
# 4  ...   3.76  3.51  1.86  0.43  2.11  2.24  17.32  6.91  0.567  21.06
#
# [5 rows x 28 columns]

# %%
college2019_data = pd.read_csv('toppick2019_records.csv')

# %%
college2019_data.head(5)
# Out:
#        player name  year  pick position  GP  GS   MIN   FGM    FGA    FG%  \
# 0  Zion Williamson  2019     1       PF  33  33  30.0  8.97  13.18  0.680
# 1        Ja Morant  2019     2        G  65  65  35.3  6.12  12.63  0.485
# 2     R.J. Barrett  2019     3       SG  38  38  35.3  8.39  18.47  0.454
# 3  De'Andre Hunter  2019     4       PF  71  38  26.6  4.35   8.55  0.509
# 4   Darius Garland  2019     5        G   5   5  27.8  5.80  10.80  0.537
#
#    ...   TRB   AST   STL   BLK    PF   TOV    PTS     WS   eFG%    PER
# 0  ...  8.88  2.06  2.12  1.79  2.06  2.36  22.61   8.51  0.708  37.86
# 1  ...  6.09  8.18  1.35  0.62  1.72  3.83  18.66  14.09  0.536  25.42
# 2  ...  7.58  4.32  0.89  0.42  1.84  3.24  22.63   6.70  0.506  22.49
# 3  ...  4.37  1.56  0.58  0.49  1.92  1.17  12.42  11.34  0.564  22.75
# 4  ...  3.80  2.60  0.80  0.40  1.40  3.00  16.20   0.65  0.639  20.70
#
# [5 rows x 28 columns]

# %%
rookie_data.describe()
# Out:
#                GP         TRB         AST         STL         BLK         PTS
# count  621.000000  621.000000  621.000000  621.000000  621.000000  621.000000
# mean    48.473430    2.645153    1.218019    0.492335    0.311514    5.678309
# std     25.201408    1.884460    1.371444    0.372407    0.343024    4.158045
# min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     27.000000    1.260000    0.370000    0.230000    0.080000    2.750000
# 50%     52.000000    2.210000    0.780000    0.410000    0.200000    4.490000
# 75%     72.000000    3.630000    1.530000    0.650000    0.450000    7.700000
# max     82.000000   12.060000    8.320000    2.240000    2.450000   22.500000

# %%
college_data.describe()
# Out:
#               year        pick          GP          GS         MIN  \
# count   621.000000  621.000000  621.000000  621.000000  621.000000
# mean   2010.932367   26.066023   81.504026   65.418680   28.632528
# std       4.499670   15.917646   37.760776   32.819033    4.952406
# min    2003.000000    1.000000   11.000000    0.000000    7.500000
# 25%    2007.000000   12.000000   40.000000   36.000000   26.000000
# 50%    2011.000000   25.000000   74.000000   65.000000   29.400000
# 75%    2015.000000   38.000000  113.000000   90.000000   32.200000
# max    2018.000000   59.000000  152.000000  147.000000   38.600000
#
#               FGM         FGA         FG%         3PM         3PA  ...  \
# count  621.000000  621.000000  621.000000  621.000000  621.000000  ...
# mean     4.722738    9.784976    0.489254    0.967939    2.644026  ...
# std      1.299464    2.832270    0.059692    0.811253    2.078336  ...
# min      1.220000    2.150000    0.350000    0.000000    0.000000  ...
# ...

# %%
college2019_data.describe()
# Out:
#          year       pick          GP          GS        MIN        FGM  \
# count    52.0  52.000000   52.000000   52.000000  52.000000  52.000000
# mean   2019.0  30.461538   77.865385   58.461538  27.709615   4.779231
# std       0.0  17.935026   38.408551   31.884265   4.010245   1.313933
# min    2019.0   1.000000    5.000000    0.000000  18.200000   2.780000
# 25%    2019.0  13.750000   37.750000   37.000000  25.500000   3.685000
# 50%    2019.0  30.500000   71.000000   56.000000  28.300000   4.590000
# 75%    2019.0  46.250000  106.500000   82.000000  29.850000   5.375000
# max    2019.0  59.000000  140.000000  135.000000  35.300000   8.970000
#
#              FGA        FG%        3PM        3PA  ...        TRB        AST  \
# count  52.000000  52.000000  52.000000  52.000000  ...  52.000000  52.000000
# mean    9.884231   0.488192   1.175385   3.219038  ...   5.187885   2.190962
# std     2.620214   0.071530   0.716096   1.912017  ...   1.758803   1.425688
# ...

# %%
rookie_data['PTS'].hist(bins=30)
plt.title('Points Histogram')
plt.xlabel('NBA Points')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
college_data['PTS'].hist(bins=30)
plt.title('Points Histogram')
plt.xlabel('College Points')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
rookie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 621 entries, 0 to 620
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   player name  621 non-null    object
#  1   GP           621 non-null    int64
#  2   TRB          621 non-null    float64
#  3   AST          621 non-null    float64
#  4   STL          621 non-null    float64
#  5   BLK          621 non-null    float64
#  6   PTS          621 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 34.1+ KB

# %%
college_data['NBAGP'] = rookie_data['GP']
college_data = college_data[college_data['NBAGP']>=20]
college_data
# Out:
#            player name  year  pick position   GP  GS   MIN   FGM    FGA  \
# 0      Carmelo Anthony  2003     3        F   35  35  36.4  7.91  17.49
# 1           Chris Bosh  2003     4       PF   31  31  31.0  5.45   9.74
# 2          Dwyane Wade  2003     5       SG   33  33  32.1  7.61  15.18
# 3          Chris Kaman  2003     6        C   31  31  34.0  7.87  12.65
# 4         Kirk Hinrich  2003     7        G   37  37  33.5  6.27  13.19
# ..                 ...   ...   ...      ...  ...  ..   ...   ...    ...
# 612     Hamidou Diallo  2018    45       SG   37  37  24.8  3.62   8.46
# 613  De'Anthony Melton  2018    46       SG   36  25  27.0  2.81   6.42
# 614   Keita Bates-Diop  2018    48       SF  109  71  24.8  4.30   9.11
# 615      Chimezie Metu  2018    49       PF  104  71  27.0  4.77   8.93
# 618       Shake Milton  2018    54       SG   87  80  34.7  4.46   9.87
#
#        FG%  ...   AST   STL   BLK    PF   TOV    PTS     WS   eFG%    PER  \
# ...

# %%
rookie_data = rookie_data[rookie_data['GP']>=20]
rookie_data
# Out:
#            player name  GP   TRB   AST   STL   BLK    PTS
# 0      Carmelo Anthony  82  6.07  2.77  1.18  0.50  21.04
# 1           Chris Bosh  75  7.43  1.04  0.79  1.41  11.48
# 2          Dwyane Wade  61  4.05  4.51  1.41  0.56  16.25
# 3          Chris Kaman  82  5.62  1.04  0.28  0.89   6.09
# 4         Kirk Hinrich  76  3.41  6.80  1.33  0.28  12.04
# ..                 ...  ..   ...   ...   ...   ...    ...
# 612     Hamidou Diallo  51  1.90  0.33  0.41  0.20   3.73
# 613  De'Anthony Melton  50  2.68  3.18  1.36  0.46   5.00
# 614   Keita Bates-Diop  30  2.77  0.57  0.60  0.47   5.03
# 615      Chimezie Metu  29  1.24  0.45  0.21  0.07   1.76
# 618       Shake Milton  20  1.75  0.90  0.40  0.40   4.35
#
# [510 rows x 7 columns]

# %%
rookie_data['PTS'].hist(bins=30)
plt.title('Points Histogram')
plt.xlabel('NBA Points')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
rookie_data.drop(columns=['player name', 'GP'],inplace=True)
rookie_data
# Out:
#       TRB   AST   STL   BLK    PTS
# 0    6.07  2.77  1.18  0.50  21.04
# 1    7.43  1.04  0.79  1.41  11.48
# 2    4.05  4.51  1.41  0.56  16.25
# 3    5.62  1.04  0.28  0.89   6.09
# 4    3.41  6.80  1.33  0.28  12.04
# ..    ...   ...   ...   ...    ...
# 612  1.90  0.33  0.41  0.20   3.73
# 613  2.68  3.18  1.36  0.46   5.00
# 614  2.77  0.57  0.60  0.47   5.03
# 615  1.24  0.45  0.21  0.07   1.76
# 618  1.75  0.90  0.40  0.40   4.35
#
# [510 rows x 5 columns]

# %%
college_data.drop(columns=['NBAGP'],inplace=True)
college_data
# Out:
#            player name  year  pick position   GP  GS   MIN   FGM    FGA  \
# 0      Carmelo Anthony  2003     3        F   35  35  36.4  7.91  17.49
# 1           Chris Bosh  2003     4       PF   31  31  31.0  5.45   9.74
# 2          Dwyane Wade  2003     5       SG   33  33  32.1  7.61  15.18
# 3          Chris Kaman  2003     6        C   31  31  34.0  7.87  12.65
# 4         Kirk Hinrich  2003     7        G   37  37  33.5  6.27  13.19
# ..                 ...   ...   ...      ...  ...  ..   ...   ...    ...
# 612     Hamidou Diallo  2018    45       SG   37  37  24.8  3.62   8.46
# 613  De'Anthony Melton  2018    46       SG   36  25  27.0  2.81   6.42
# 614   Keita Bates-Diop  2018    48       SF  109  71  24.8  4.30   9.11
# 615      Chimezie Metu  2018    49       PF  104  71  27.0  4.77   8.93
# 618       Shake Milton  2018    54       SG   87  80  34.7  4.46   9.87
#
#        FG%  ...    TRB   AST   STL   BLK    PF   TOV    PTS     WS   eFG%  \
# ...

# %%
df=pd.concat([college_data,rookie_data], axis=1)
df
# Out:
#            player name  year  pick position   GP  GS   MIN   FGM    FGA  \
# 0      Carmelo Anthony  2003     3        F   35  35  36.4  7.91  17.49
# 1           Chris Bosh  2003     4       PF   31  31  31.0  5.45   9.74
# 2          Dwyane Wade  2003     5       SG   33  33  32.1  7.61  15.18
# 3          Chris Kaman  2003     6        C   31  31  34.0  7.87  12.65
# 4         Kirk Hinrich  2003     7        G   37  37  33.5  6.27  13.19
# ..                 ...   ...   ...      ...  ...  ..   ...   ...    ...
# 612     Hamidou Diallo  2018    45       SG   37  37  24.8  3.62   8.46
# 613  De'Anthony Melton  2018    46       SG   36  25  27.0  2.81   6.42
# 614   Keita Bates-Diop  2018    48       SF  109  71  24.8  4.30   9.11
# 615      Chimezie Metu  2018    49       PF  104  71  27.0  4.77   8.93
# 618       Shake Milton  2018    54       SG   87  80  34.7  4.46   9.87
#
#        FG%  ...   TOV    PTS     WS   eFG%    PER   TRB   AST   STL   BLK  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 510 entries, 0 to 618
# Data columns (total 33 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   player name  510 non-null    object
#  1   year         510 non-null    int64
#  2   pick         510 non-null    int64
#  3   position     510 non-null    object
#  4   GP           510 non-null    int64
#  5   GS           510 non-null    int64
#  6   MIN          510 non-null    float64
#  7   FGM          510 non-null    float64
#  8   FGA          510 non-null    float64
#  9   FG%          510 non-null    float64
#  10  3PM          510 non-null    float64
#  11  3PA          510 non-null    float64
#  12  3P%          510 non-null    float64
#  13  FTM          510 non-null    float64
#  14  FTA          510 non-null    float64
#  15  FT           510 non-null    float64
#  16  OFF          510 non-null    float64
#  17  DEF          510 non-null    float64
# ...
